# %%
import pandas as pd

print("I am working")
# Out:
# I am working

# %%
fatura_data = pd.read_excel("2022_db_conn_tbl.xlsx")
print("file read")
# Out:
# file read

# %%
fatura_data.shape
# Out:
# (314631, 78)

# %%
fatura_data.describe()
# Out:
#           FI_BLG_YIL        FI_BLG        FTR_NO        FTR_KLM        SIP_NO  \
# count  314631.000000  3.083550e+05  3.146310e+05  314631.000000  3.145960e+05
# mean     1981.666810  2.000014e+09  5.093736e+09     643.432141  5.013669e+09
# std       282.713987  8.006914e+03  8.599312e+05    1174.108454  8.962616e+05
# min         0.000000  2.000000e+09  5.093192e+09      10.000000  5.013101e+09
# 25%      2022.000000  2.000007e+09  5.093199e+09      31.000000  5.013108e+09
# 50%      2022.000000  2.000014e+09  5.093206e+09      71.000000  5.013112e+09
# 75%      2022.000000  2.000021e+09  5.095023e+09     453.000000  5.015013e+09
# max      2022.000000  2.000028e+09  5.099001e+09    4072.000000  5.019001e+09
#
#              SIP_KLM           MST       MAL_GRB        MLZ_GRB  \
# count  314631.000000  3.146310e+05  3.146310e+05  184717.000000
# mean      407.527453  1.200998e+09  4.771876e+07       6.767000
# std       805.727466  1.545978e+06  1.990442e+07       9.708677
# ...
